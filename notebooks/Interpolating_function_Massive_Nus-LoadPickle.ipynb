# %% [markdown]
# # Emulating the data for MassiveNus

# %% [markdown]
# ## Import Packages

# %%
import os
import sys
import numpy as np
import pandas as pd
import time
from scipy import interpolate

# %%
from looti import dictlearn as dcl
from looti import datahandle as dhl
from looti import PlottingModule as pm

from looti import tools as too
from looti import PlottingModule as pm
from looti import interpolatingObject as ito

# %%
import pickle
import joblib

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load and save the interpolation function

# %%
with open('./massiveNus-interpObj.sav', 'rb') as f:
    Interpolation_loaded = joblib.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b01f29b5cf2a> in <module>
# ----> 1 with open('./massiveNus-interpObj.sav', 'rb') as f:
#       2     Interpolation_loaded = joblib.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './massiveNus-interpObj.sav'

# %%
kgridlog = np.linspace(np.log10(0.0125),np.log10(8.5),200)
kgridlog;

# %%
Interpolation_loaded.predict(0.0,0.1,[0.06271,0.38154,2.2004])
# Out:
# 1.282904184549968

# %%
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.06271,0.33154,2.2004]) for k in np.power(10,kgridlog) ])
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.06271,0.32154,2.2004]) for k in np.power(10,kgridlog) ])

# %%
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.06271,0.33154,2.2004]) for k in np.power(10,kgridlog) ])
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.04271,0.33154,2.2004]) for k in np.power(10,kgridlog) ])

# %%
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.6,0.3,2.1]) for k in np.power(10,kgridlog) ])
plt.semilogx(np.power(10,kgridlog),[Interpolation_loaded.predict(0.0,k,[0.,0.3,2.1]) for k in np.power(10,kgridlog) ])

# %%
[Interpolation_loaded.predict(0.0,k,[0.,0.3,2.1]) for k in np.power(10,kgridlog) ]
# Out:
# [0.8012139844192072,
#  0.8014469584959016,
#  0.8016876946468059,
#  0.8019364514835083,
#  0.8021934962338451,
#  0.8024591050289703,
#  0.802733563199991,
#  0.8030171655844844,
#  0.8033102168432295,
#  0.8036130317874879,
#  0.8039259357171928,
#  0.8041496070270052,
#  0.8043794514579992,
#  0.804616953691764,
#  0.8048623688658424,
#  0.8051159606182786,
#  0.8053780013708324,
#  0.8055575166065271,
#  0.8057200748894489,
#  0.8058880491803375,
#  0.8060616199261182,
#  0.8062375730824899,
#  0.8064144746651165,
#  0.8065972701361606,
#  0.8067854204578139,
#  0.8068947327203569,
#  0.8070076869756314,
#  0.8071216454700485,
#  0.8072298617307295,
#  0.8073416834682859,
#  0.807457230807581,
#  0.8075766278757176,
#  0.8075031604048823,
#  0.8073872982027894,
#  0.807234917861092,
#  0.8072362162675497,
#  0.8074478720781196,
#  0.8073514233231581,
#  0.8073985124077814,
#  0.8073886499821495,
#  0.8073187698011485,
#  0.8075524637056111,
#  0.8076828721524586,
# ...
