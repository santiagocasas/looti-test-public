# %%
import numpy as np
import pandas as pd
from numpy.random import multivariate_normal
import tempfile
import os
from chainconsumer import ChainConsumer

# %%
chain_fits=np.loadtxt('./results/flat_chain_5000_intp_fits.txt')

# %%
chain_codecs=np.loadtxt('./results/flat_chain_5000_intp_codecs.txt')

# %%
parameters=['$\\Omega_m$', '$\\beta$']

# %%
truth=[0.32,0.10]

# %%
chain_fits_cut = chain_fits[1000:]
chain_codecs_cut= chain_codecs[1000:]

# %%
c = ChainConsumer().add_chain(chain_fits_cut, parameters=parameters, name='Fits')
#c = ChainConsumer().add_chain(chain_codecs_cut, parameters=parameters, name='Codecs')

# %%
fig = c.plotter.plot(truth=truth, extents=[[0.3015, 0.303], [0.082, 0.083]])
fig.set_size_inches(2.5 + fig.get_size_inches())

# %%
fig.savefig('mcmc-test.png')
