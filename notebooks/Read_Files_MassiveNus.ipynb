# %% [markdown]
# ## Import Packages

# %%
import os
import sys
import numpy as np
import errno

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.gridspec as gridspec
from matplotlib.pyplot import cm
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)

import pandas as pd
import random as rn
from itertools import cycle
import time
from collections import OrderedDict

# %%
from looti import emulatorpaths as epath

#from looti  import tools as too
from looti  import interpolators as itp

from looti import dataplotters as dtp

from looti import dictlearn as dcl

from looti import datahandle as dhl

#sns.set()

# %%
from looti import read_file as rf

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# # Run Parameters

# %% [markdown]
# ## Import Data

# %% [markdown]
# The user must provide the folder where the data are stored : Datafolder.
# It is expected that inside this folder, the data are organised in the following way :
# - One folder per parameters
# - These folders must contain the names/abreviations and values of the parameters used within its name.
# - The parameters'names must be seperated by a character e.g : _ , -- , ;
# - Each of these folders contains files where is stored the matter power spectrum or ratio at given redshifts.
# - The name of these files should contains the snapshot/redshift
#
# Considering the following path as an exemple : MassiveNus/mnv0.00000_om0.30000_As2.1000/powerspec_tot_034.txt
# - Datafolder is MassiveNus
# - Parameters names are mnv,om,As and they are separated by : " _ "
# - The folder mnv0.00000_om0.30000_As2.1000 contains the power matter spetrum for these parameters for different redshift e.g powerspec_tot_034.txt for snapshot "034"

# %% [markdown]
# Indicate the name path of the datafolder :

# %%
datafolder = '../../MassiveNus-matterpower/'

# %%
os.path.isdir(datafolder) #Check if the folder exists
# Out:
# True

# %%
#rf.ask_param(os.listdir(datafolder))

# %% [markdown]
# # Read the parameters names and seperation

# %% [markdown]
# The following function will read the first file within the datafolder. It will assume that this file is a relevant example. As explained above this file should contains the name of the parameters seperated by a character and the values of the parameters.
#
# The function will asks the user to provide the names of the parameters and the seperations used.

# %% [markdown]
# #  Construct the frame

# %% [markdown]
# The following function will construct the dataframe.
# If the function ask_param has been runned the user should only change the following parameters :
# - feature_filename : the begining of the files'name containing the values of matter power spectrum/ratio
# - filename_format : the format of the files'name containing the values of matter power spectrum/ratio
# - grid_pos : the column which contains the grid, e.g, grid_pos=0 would assume that the grid corresponds to the first column
# - feature_pos=1 : the column which contains matter power spectrum/ratio, e.g feature_pos=1 would assume that the features are in the second column.

# %%
data_frame=rf.create_DataFrame(config_file="notebooks/config-fofR.yaml")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-09a4ff9cc46d> in <module>
# ----> 1 data_frame=rf.create_DataFrame(config_file="notebooks/config-fofR.yaml")
#
# TypeError: create_DataFrame() got an unexpected keyword argument 'config_file'

# %%
####Run to construct the database
data_frame=rf.create_DataFrame()

# %%
ls "../data/Massive_Nus.csv"
# Out:
# ../data/Massive_Nus.csv

# %%
data = pd.read_csv("../data/Massive_Nus.csv", index_col=[0,1,2,3,4,5,6,7])

# %%
parameter_indexname = [nn for nn in list(data.index.names) if ( 'param' in nn and 'value' not in nn)]

# %%
data.loc["theo"]
# Out:
#                                                                                                                0  \
# redshift parameter_1 parameter_1_value parameter_2 parameter_2_value parameter_3 parameter_3_value
# 19.0     mnv         0.09041           om          0.28447           As          2.1757             3.164010e+10
# 25.0     mnv         0.09041           om          0.28447           As          2.1757             8.745360e+10
# 31.0     mnv         0.09041           om          0.28447           As          2.1757             2.038910e+11
# 47.0     mnv         0.09041           om          0.28447           As          2.1757             9.231670e+12
# 53.0     mnv         0.09041           om          0.28447           As          2.1757             1.330890e+13
# ...                                                                                                          ...
# 28.0     mnv         0.38317           om          0.28566           As          1.4164
\
# noise_model redshift parameter_1 parameter_1_value parameter_2 parameter_2_value parameter_3 parameter_3_value
# theo        0.0      mnv         0.00000           om          0.30000           As          2.1000             2.327540e+09
#                                  0.06271           om          0.38154           As          2.2004             4.143040e+09
#                                  0.06522           om          0.28205           As          1.8826             1.479570e+09
#                                  0.06773           om          0.41591           As          1.6231             3.413290e+09
#                                  0.07024           om          0.20235           As          2.3075             8.631710e+08
# ...                                                                                                                      ...
#             79.0     mnv         0.11351           om          0.18409           As          1.7932             4.267610e+09
#             80.0     mnv         0.11351           om          0.18409           As          1.7932             4.637680e+09
#             81.0     mnv         0.11351           om          0.18409           As          1.7932             4.637680e+09
#             82.0     mnv         0.11351           om          0.18409           As          1.7932             4.637680e+09
# k_grid      NaN      NaN         NaN               NaN         NaN               NaN         NaN                1.873360e-02
#
#                                                                                                                          692  \
# noise_model redshift parameter_1 parameter_1_value parameter_2 parameter_2_value parameter_3 parameter_3_value
# theo        0.0      mnv         0.00000           om          0.30000           As          2.1000             2.583230e+09
#                                  0.06271           om          0.38154           As          2.2004             4.652830e+09
#                                  0.06522           om          0.28205           As          1.8826             1.637640e+09
#                                  0.06773           om          0.41591           As          1.6231             3.823930e+09
#                                  0.07024           om          0.20235           As          2.3075             9.456470e+08
# ...                                                                                                                      ...
#             79.0     mnv         0.11351           om          0.18409           As          1.7932             4.631520e+09
#             80.0     mnv         0.11351           om          0.18409           As          1.7932             4.991380e+09
#             81.0     mnv         0.11351           om          0.18409           As          1.7932             4.991380e+09
#             82.0     mnv         0.11351           om          0.18409           As          1.7932             4.991380e+09
# k_grid      NaN      NaN         NaN               NaN         NaN               NaN         NaN                1.888020e-02
#
#                                                                                                                          693  \
# noise_model redshift parameter_1 parameter_1_value parameter_2 parameter_2_value parameter_3 parameter_3_value
# theo        0.0      mnv         0.00000           om          0.30000           As          2.1000             2.827000e+09
#                                  0.06271           om          0.38154           As          2.2004             5.167400e+09
#                                  0.06522           om          0.28205           As          1.8826             1.768950e+09
#                                  0.06773           om          0.41591           As          1.6231             4.213950e+09
#                                  0.07024           om          0.20235           As          2.3075             1.030870e+09
# ...                                                                                                                      ...
#             79.0     mnv         0.11351           om          0.18409           As          1.7932             4.901590e+09
#             80.0     mnv         0.11351           om          0.18409           As          1.7932             5.372240e+09
#             81.0     mnv         0.11351           om          0.18409           As          1.7932             5.372220e+09
#             82.0     mnv         0.11351           om          0.18409           As          1.7932             5.372220e+09
# k_grid      NaN      NaN         NaN               NaN         NaN               NaN         NaN                1.901130e-02
#
#                                                                                                                          694
# noise_model redshift parameter_1 parameter_1_value parameter_2 parameter_2_value parameter_3 parameter_3_value
# theo        0.0      mnv         0.00000           om          0.30000           As          2.1000             4.231990e+09
#                                  0.06271           om          0.38154           As          2.2004             4.777350e+09
#                                  0.06522           om          0.28205           As          1.8826             3.090530e+09
#                                  0.06773           om          0.41591           As          1.6231             3.489790e+09
#                                  0.07024           om          0.20235           As          2.3075             2.503660e+09
# ...                                                                                                                      ...
#             79.0     mnv         0.11351           om          0.18409           As          1.7932             4.136560e+10
#             80.0     mnv         0.11351           om          0.18409           As          1.7932             4.991770e+09
#             81.0     mnv         0.11351           om          0.18409           As          1.7932             4.991990e+09
#             82.0     mnv         0.11351           om          0.18409           As          1.7932             4.991990e+09
# k_grid      NaN      NaN         NaN               NaN         NaN               NaN         NaN                1.912990e-02
#
# [6982 rows x 695 columns]

# %%
data.loc["theo",:,"mnv","0.15954"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: '0.15954'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# TypeError: must be real number, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d4952a2a1adc> in <module>
# ----> 1 data.loc["theo",:,"mnv","0.15954"]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1371         # we may have a nested tuples indexer here
#    1372         if self._is_nested_tuple_indexer(tup):
# -> 1373             return self._getitem_nested_tuple(tup)
#    1374
#    1375         # we maybe be using a tuple to represent multiple dimensions here
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#    1431         # a tuple passed to a series with a multi-index
#    1432         if len(tup) > self.ndim:
# -> 1433             result = self._handle_lowerdim_multi_index_axis0(tup)
#    1434             if result is not None:
#    1435                 return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _handle_lowerdim_multi_index_axis0(self, tup)
#    1358             # else IndexingError will be raised
#    1359             if len(tup) <= self.obj.index.nlevels and len(tup) > self.ndim:
# -> 1360                 raise ek
#    1361
#    1362         return None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _handle_lowerdim_multi_index_axis0(self, tup)
#    1350         try:
#    1351             # fast path for series or for tup devoid of slices
# -> 1352             return self._get_label(tup, axis=axis)
#    1353         except TypeError:
#    1354             # slices are unhashable
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3533         index = self.index
#    3534         if isinstance(index, MultiIndex):
# -> 3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
#    3537             loc = self.index.get_loc(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2821                 for i, k in enumerate(key):
#    2822                     if not isinstance(k, slice):
# -> 2823                         k = self._get_level_indexer(k, level=i)
#    2824                         if isinstance(k, slice):
#    2825                             # everything
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2927         else:
#    2928
# -> 2929             code = self._get_loc_single_level_index(level_index, key)
#    2930
#    2931             if level > 0 or self.lexsort_depth == 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2596             return -1
#    2597         else:
# -> 2598             return level_index.get_loc(key)
#    2599
#    2600     def get_loc(self, key, method=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py in get_loc(self, key, method, tolerance)
#     506         except (TypeError, NotImplementedError):
#     507             pass
# --> 508         return super().get_loc(key, method=method, tolerance=tolerance)
#     509
#     510     @cache_readonly
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: '0.15954'

# %%
for i in data.loc["theo",19,:].index:
    print(data.loc[("theo",19)+i])

# %%
data.loc[("theo", 19)+i]

# %%
("theo", 19)+i

# %%
("theo", 19)+i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ac985b70f07d> in <module>
# ----> 1 ("theo", 19)+i
#
# NameError: name 'i' is not defined

# %%
data.loc[('theo', 19, 'mnv', i[1])]# 'om', 0.2118)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-00fa5169c307> in <module>
# ----> 1 data.loc[('theo', 19, 'mnv', i[1])]# 'om', 0.2118)]
#
# NameError: name 'i' is not defined

# %%
i[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6e3b76e446eb> in <module>
# ----> 1 i[1]
#
# NameError: name 'i' is not defined

# %%
data.loc[('theo', 19, 'mnv',0.29147)]
# Out:
# /Users/raphaelbaena/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                                                                         0  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             1.751500e+11
#
#                                                                         1  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             1.114950e+11
#
#                                                                         2  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             7.697700e+10
#
#                                                                         3  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             5.581620e+10
#
#                                                                         4  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             4.218380e+10
#
#                                                                         5  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             3.294070e+10
#
#                                                                         6  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             2.172510e+10
#
#                                                                         7  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             1.786100e+10
#
#                                                                         8  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             1.489430e+10
#
#                                                                         9  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             1.293420e+10
#
#                                                              ...       685  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value  ...
# om          0.31082           As          2.2697             ...  0.007751
#
#                                                                   686  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.008178
#
#                                                                   687  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.008628
#
#                                                                   688  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.009126
#
#                                                                   689  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.009598
#
#                                                                   690  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.010217
#
#                                                                   691  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.010778
#
#                                                                  692  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.01142
#
#                                                                   693  \
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.012119
#
#                                                                   694
# parameter_2 parameter_2_value parameter_3 parameter_3_value
# om          0.31082           As          2.2697             0.000823
#
# [1 rows x 695 columns]
