# %% [markdown]
# ## Import Packages

# %%
import os
import sys
import numpy as np
import errno

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.gridspec as gridspec
from matplotlib.pyplot import cm
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)

import pandas as pd
import random as rn
from itertools import cycle
import time
from collections import OrderedDict

# %%
from looti import emulatorpaths as epath

#from looti  import tools as too
from looti  import interpolators as itp

from looti import dataplotters as dtp

from looti import dictlearn as dcl

from looti import datahandle as dhl

#sns.set()

# %%
from looti import read_file as rf

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# # Run Parameters

# %% [markdown]
# ## Import Data

# %% [markdown]
# The user must provide the folder where the data are stored : Datafolder.
# It is expected that inside this folder, the data are organised in the following way :
# - One folder per parameters
# - These folders must contain the names/abreviations and values of the parameters used within its name.
# - The parameters'names must be seperated by a character e.g : _ , -- , ;
# - Each of these folders contains files where is stored the matter power spectrum or ratio at given redshifts.
# - The name of these files should contains the snapshot/redshift
#
# Considering the following path as an exemple : MassiveNus/mnv0.00000_om0.30000_As2.1000/powerspec_tot_034.txt
# - Datafolder is MassiveNus
# - Parameters names are mnv,om,As and they are separated by : " _ "
# - The folder mnv0.00000_om0.30000_As2.1000 contains the power matter spetrum for these parameters for different redshift e.g powerspec_tot_034.txt for snapshot "034"

# %% [markdown]
# Indicate the name path of the datafolder :

# %%
datafolder = '../../MassiveNus-matterpower/'

# %%
os.path.isdir(datafolder) #Check if the folder exists
# Out:
# True

# %%
#rf.ask_param(os.listdir(datafolder))

# %% [markdown]
# # Read the parameters names and seperation

# %% [markdown]
# The following function will read the first file within the datafolder. It will assume that this file is a relevant example. As explained above this file should contains the name of the parameters seperated by a character and the values of the parameters.
#
# The function will asks the user to provide the names of the parameters and the seperations used.

# %%
param_str_array,sep_param,sep_param_value = rf.ask_param(datafolder)
# Out:
# Please provide the name of parameters which are indicated in this file and separates them with a comma e.g :  mnv,om,As
#  Name of the first folder in main directory : .
#  => give the list of parameters of this file, separated by comma, no spaces : mnv,om,As
# Is there a separation between the parameter name and value ? (y/n) : n
# Provide the separation between each (parameter,value) pair, e.g. (-, _, --) : _

# %% [markdown]
# #  Construct the frame

# %% [markdown]
# The following function will construct the dataframe.
# If the function ask_param has been runned the user should only change the following parameters :
# - feature_filename : the begining of the files'name containing the values of matter power spectrum/ratio
# - filename_format : the format of the files'name containing the values of matter power spectrum/ratio
# - grid_pos : the column which contains the grid, e.g, grid_pos=0 would assume that the grid corresponds to the first column
# - feature_pos=1 : the column which contains matter power spectrum/ratio, e.g feature_pos=1 would assume that the features are in the second column.

# %%
### The parameters that the user should change :
feature_filename="powerspec_tot_" ### Beginning of the files'names containing the features
filename_format="txt"  #extension of the files 
grid_pos=0 # column corresponding to the grid
feature_pos=1 # column corresponding to the features

# %%
####Run to construct the database
data_frame=rf. create_DataFrame(datafolder,param_str_array, sep_param, sep_param_value,


                     feature_filename=feature_filename, filename_format=filename_format,
                     
                     grid_pos=grid_pos, feature_pos=feature_pos)
# Out:
# <class 'ValueError'>
# <class 'ValueError'>
# /Users/raphaelbaena/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: PerformanceWarning: indexing past lexsort depth may impact performance.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_frame
# Out:
#                                                                                                                         0    \
# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757

# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757              2.7274e+09
#             025      mnv         0.09041           om          0.28447           As          2.1757             1.22197e+09
#             031      mnv         0.09041           om          0.28447           As          2.1757             1.10666e+09
#             030      mnv         0.09041           om          0.28447           As          2.1757             1.08211e+09
#             024      mnv         0.09041           om          0.28447           As          2.1757              1.3339e+09
# ...                                                                                                                     ...
#             015      mnv         0.38317           om          0.28566           As          1.4164             7.05842e+09
#             029      mnv         0.38317           om          0.28566           As          1.4164              1.1249e+09
#             028      mnv         0.38317           om          0.28566           As          1.4164             1.20211e+09
#             014      mnv         0.38317           om          0.28566           As          1.4164             7.86526e+09
#             000      mnv         0.38317           om          0.28566           As          1.4164             1.05263e+09
#
#                                                                                                                         691  \
# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757             3.03025e+09
#             025      mnv         0.09041           om          0.28447           As          2.1757             1.32964e+09
#             031      mnv         0.09041           om          0.28447           As          2.1757             1.19809e+09
#             030      mnv         0.09041           om          0.28447           As          2.1757             1.17103e+09
#             024      mnv         0.09041           om          0.28447           As          2.1757             1.45909e+09
# ...                                                                                                                     ...
#             015      mnv         0.38317           om          0.28566           As          1.4164             8.25758e+09
#             029      mnv         0.38317           om          0.28566           As          1.4164             1.22471e+09
#             028      mnv         0.38317           om          0.28566           As          1.4164             1.30907e+09
#             014      mnv         0.38317           om          0.28566           As          1.4164             9.28467e+09
#             000      mnv         0.38317           om          0.28566           As          1.4164             1.17747e+09
#
#                                                                                                                         692  \
# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757             3.37928e+09
#             025      mnv         0.09041           om          0.28447           As          2.1757             1.44494e+09
#             031      mnv         0.09041           om          0.28447           As          2.1757             1.29329e+09
#             030      mnv         0.09041           om          0.28447           As          2.1757             1.26815e+09
#             024      mnv         0.09041           om          0.28447           As          2.1757             1.58526e+09
# ...                                                                                                                     ...
#             015      mnv         0.38317           om          0.28566           As          1.4164             9.36185e+09
#             029      mnv         0.38317           om          0.28566           As          1.4164             1.32934e+09
#             028      mnv         0.38317           om          0.28566           As          1.4164             1.42544e+09
#             014      mnv         0.38317           om          0.28566           As          1.4164             1.06995e+10
#             000      mnv         0.38317           om          0.28566           As          1.4164             1.30265e+09
#
#                                                                                                                         693  \
# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757             3.66584e+09
#             025      mnv         0.09041           om          0.28447           As          2.1757              1.5644e+09
#             031      mnv         0.09041           om          0.28447           As          2.1757             1.41835e+09
#             030      mnv         0.09041           om          0.28447           As          2.1757             1.36876e+09
#             024      mnv         0.09041           om          0.28447           As          2.1757             1.71729e+09
# ...                                                                                                                     ...
#             015      mnv         0.38317           om          0.28566           As          1.4164             1.04554e+10
#             029      mnv         0.38317           om          0.28566           As          1.4164             1.46037e+09
#             028      mnv         0.38317           om          0.28566           As          1.4164             1.54207e+09
#             014      mnv         0.38317           om          0.28566           As          1.4164             1.19572e+10
#             000      mnv         0.38317           om          0.28566           As          1.4164             1.40172e+09
#
#                                                                                                                         694
# noise_model redshift parameter_0 parameter_0_value parameter_1 parameter_1_value parameter_2 parameter_2_value
# theo        019      mnv         0.09041           om          0.28447           As          2.1757             2.62074e+07
#             025      mnv         0.09041           om          0.28447           As          2.1757             8.68143e+08
#             031      mnv         0.09041           om          0.28447           As          2.1757             1.35607e+08
#             030      mnv         0.09041           om          0.28447           As          2.1757             1.12861e+09
#             024      mnv         0.09041           om          0.28447           As          2.1757             2.15618e+08
# ...                                                                                                                     ...
#             015      mnv         0.38317           om          0.28566           As          1.4164             1.19546e+10
#             029      mnv         0.38317           om          0.28566           As          1.4164             9.41536e+08
#             028      mnv         0.38317           om          0.28566           As          1.4164             1.07644e+09
#             014      mnv         0.38317           om          0.28566           As          1.4164             3.84969e+10
#             000      mnv         0.38317           om          0.28566           As          1.4164             2.79003e+09
#
# [7052 rows x 695 columns]
